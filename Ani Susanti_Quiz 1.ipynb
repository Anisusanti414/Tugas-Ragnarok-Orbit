# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Python OOP

# %% [markdown]
# 1.  Suatu metode pemrograman yang berorientasi pada objek. Program-program yang telah ada merupakan gabungan dari beberapa komponen-komponen kecil yang sudah ada sebelumnya

# %%
nama = "Ani"
usia = 22
prodi = "Matematika"
fakultas = "STEM"

def data():
    print("Data Mahasiswa")

def data_mahasiswa(nama, usia, prodi, fakultas):
    print(f"nama: {nama}, usia: {usia}, prodi: {prodi}, fakultas: {fakultas}")

data_mahasiswa(nama, usia, prodi, fakultas)
data()
# Out:
# nama: Ani, usia: 22, prodi: Matematika, fakultas: STEM
# Data Mahasiswa

# %%
class planet(object):
    def __init__(self, nama, usia):
        self.nama = nama
        self.usia = usia
        
    def galaxy(self, bima_sakti):
        for x in range(bima_sakti):
            print("ddrrr... ddrrr... ")

    def info(self):
        print(f"nama: {self.nama}, usia: {self.usia}")


planet1 = planet("Bumi", 250000)

planet1.info()
# Out:
# nama: Bumi, usia: 250000

# %% [markdown]
# 2. math untuk melakukan operational pada bilangan numerik. random untuk melakukan pemilihan data/angka secar arandom

# %% [markdown]
# 3.

# %%
import math
a = math.isqrt(175)
b = 4 * math.isqrt(7)
c = 1/3
d = math.log(81,3)

# %%
print(a+b+c+d)
# Out:
# 25.333333333333332

# %% [markdown]
# 4. costum exception handling adalah cara untuk membuat kelas baru namun terdapat exception yang berfungi untuk melakukan penyesuaian pada kelas baik secara langsung atau tidak langsung.

# %%
x = int(input("masukan angka 1 :"))
y = int(input("masukan angka 2 :"))

try:
    hasil = x/y
    print('hasil pembagian angka 1 dan 2 adalah :', hasil)
except:
    print("Tidak bisa, pembagian angka dengan 0")
# Out:
# masukan angka 1 :2
# masukan angka 2 :0
# Tidak bisa, pembagian angka dengan 0

# %% [markdown]
# ## AI

# %% [markdown]
# 1. Data terstruktur merupakan data yang yang dapat diproses, disimpan, dan diambil dalam format tetap. contoh data yang di ambil dari pertanyaan kuisioner, data nilai saham, data dari sebuah sekolah atau perusahaan. Sedangkan data unstructure merupakan data yang tidak memiki stuktur yang jelas sehingga sulit untuk di proses, contohnya data berupa gambar, suara, dan lain-lain

# %% [markdown]
# 2. Artificial Intelligence (kecerdasan buatan – AI) merupakan teknologi masa kini yang konsepnya “membawa kepintaran manusia ke dalam mesin.”
#
# Sedangkan Machine Learning adalah bagian dari implementasi Artificial Intelligence. Machine Learning merupakan metode pembelajaran AI yang memanfaatkan data untuk membuat prediksi layaknya manusia.
#
# Deep Learning merujuk pada salah satu algoritma yang digunakan oleh Machine Learning dalam Artificial Intelligence. Deep Learning memanfaatkan berbagai variable kompleks dalam analisisnya, sehingga mesin bisa memahami suatu pola atau kebiasaan yang timbul dari suatu kejadian.

# %% [markdown]
# 3. Mechine learning sudah algortima di dalam komputer yang dibuat oleh manusia, sehingga dari data-data yang dimasukan mecine sudah bisa melakukan analisa atau prediksi dari datanya.
#
# Tradisional software masih membutuhkan manusia untuk melakukan analisa atau prediksi, sehingga tidak secara otomatis diberikan oleh komputer.

# %% [markdown]
# 4.
#
# sector smart city : pediksi harga rumah, prediksi harga saham, prediksi inflasi
#
# agricalture : prediksi hujan, prediksi harga kebutuhan makanan, prediksi hasil panen

# %% [markdown]
# ## Math AI

# %% [markdown]
# 1. Karena didalam AI, prosesnya dilakukan secara matematika.

# %% [markdown]
# 2. Vektor adalah besaran yang merepresentasikan dengan nilai dan arah, sedangkan skalar adalah besaran yang merepresentasikan nilai saja

# %% [markdown]
# 3. ED -> menghitung jarak dengan mengakar kuadratkan hasil pengurangan yang sudah di kuadratkan.
# Manhattam -> menghitung dengan memutlkankan hasil pengurangan jaraknya
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Kegunaan matriks dalam ilmu AI yaitu untuk menghitung proses-proses yang dilakukan algoritma didalamnya. contohnya pada pemrosesan data gambar, maka gambar akan di ubah atau di baca menggunakan matriks yang nantinya akan di proses sehingga akhirnya bisa mendapatkan output

# %% [markdown]
# ### Mechine Learning

# %% [markdown]
# 1. Supervised learning -> punya target variabel. fungsinya untuk prediksi atau clasifikasi(Decision tree, Random Forest).
# Unsupervised learning -> tidak punya target variabel. fungsinya biasanya untuk clustering atau association (DBSCAN, KNN)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. menentukan tujuan dari penelitian, lalu mengumpulkan data-data yang diperlukan. setelah data terkumpul maka bisa menyiapkan data dengan melakukan cleaning dan lain-lain. Lalu memilih algoritma atau model apa yang mau di pakai dan sesuai dengan permasalahan dan casas nya. lalu latih model untuk mendapatkan akurasi modelnya. setelah model terbentuk dari dat alatih, maka kita harus melakukan testing menggunakan data testing untuk mengetahui seberapa baik model yang sudah kita buat. setelah itu lakukan integrasi model jika modelnya sudah baik

# %% [markdown]
# 3. Regresi masuk ke metode supervised learning, yang berfungsi untuk mengestimasi suatu nilai. Sedangkan clustering masuk ke unsupervised learning yang berfngsi untuk menentukan variabel masuk ke kluster apa dan ada berapa cluster

# %% [markdown]
# 4. ANN merupakan jaringan dari sekelompok unit pemroses kecil yang dimodelkan berdasarkan perilaku jaringan syaraf manusia.fungsinya untuk mnegklasifikasi,memetakan pola, dan lain-lain.
